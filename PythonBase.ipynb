# %%
# ①データ型 まとめ　　　　　　　　　　　　　　　　　　　　　　　コンテナ型(複数の変数を持てる)
#    int 整数　integerの略                                         list リスト　複数の変数を持てて、その変更が可能(後にリストの説明あり)
#    float 浮動小数点  小数を扱う                                  tuple タプル　複数の変数が持てるが、変更は不可能(ここから下の型は教えてない)
#    str 文字列 string(文字列)の略　　　　　　　　　　　　　　　　 dict 辞書(dictionary) 2つのデータを関連付けて複数の変数を持つことができる
#    bool 真偽値 人名由来 true または falseの二つのみを値に持つ　　set セット　順番に関係なく変数を持つ

# ②変数 何書いて良いか分かんないから授業でなんかあったら随時更新してね
#    イコールは代入の記号
#    a = a + 1　は元のaに1を足す
#    データ型を宣言する場合　「変数名: データ型 = 値」 例:x: int = 0

# ③組み込み関数
# データ型変換に使う int()やfloat()とかも一応組み込み関数らしい

# ④メソッド

# ⑤条件式に使う比較演算の記号
#    == イコール　!= ノットイコール　> 大なり　< 小なり　>= 大なりイコール　<= 小なりイコール
#    and かつ　or または

# ⑥条件分岐
#    if 条件式: 
#      関数     で条件式が満たされているときのみ関数を処理する(このとき関数はifより右で揃える)

# ⑦リスト
#    変数名 = [値1, 値2, 値3,・・・]でリスト作成　n個の変数を入れる場合、左から順に変数名[0],変数名[1],・・・,変数名[n-1]となる
#    for i in range(0, n):   でループ処理をすることでn個の異なる変数に同じ処理をすることができるので
#                            「異なる変数に同じ処理がしたい」ときに特に有用

#    変数名[n-1] = 値 という処理でn番目の値を変えることができる

# ⑧ループ1 for (ループ回数を明確に決めたいとき or 変数の増え幅を固定させたいとき　などに有効)
#    for 変数名 in range(最初の値, おわりの値, 増え幅): 
#       関数                                               で変数がおわりの値以上になるまで関数の処理を繰り返す
#                                                          おわりの値がn、増え幅が1の時出力はn-1までだが、変数には最終的にnが入っている

# ⑨ループ2 while (回数が決まっていないなど、forでのループに向いていないとき全般に有用)
#    while 条件式:
#       関数       で条件式が満たされ続ける限り関数の処理を繰り返す
#                  「～が満たされるまでループ」としたい場合は「～が満たされない限りループ」を意識して条件式を書こう

# ⑩その他
#    print関数
#       print("文字列") で文字列を表示させることができる

#    format関数
#       print("～{}～{}～". format(変数1, 変数2)) で{}に変数を入れて表示できる　※変数の部分には式を入れることもできる(変数1 + 変数2 - 3 なども可能)

#    type関数
#       print(type(変数)) で変数のデータ型を表示できる

#    input関数
#       変数 = input() で入力された文字列を変数に代入できる　input("文字列")とすると文字列を表示した後入力フォームが出現する
#       変数 = データ型(input()) で数値などを入力した際にintやfloatに変換できる ※変換できない値が入力された場合はエラーになるので対策にtry-except文を使うと良いらしい

#    try-except文
#       try:
#          エラーが発生するかもしれないプログラム
#       except:
#          例外発生時に行いたいプログラム           とすると操作の違いなどによるエラーを防ぐことができる 
#                                                   ※ただし、プログラムの強制終了も例外に含まれるのでこのタイミングで強制終了はできない(詳細にエラー内容を絞ればできるけどむずい)

#    import random(下記のものを使う場合最初に記述)による乱数
#       1	random.random()	数字をランダムに表示
#       2	random.randint ( 最小値 , 最大値 )	ランダムに一つだけint値（整数値）を表示
#       3	random.uniform ( 最小値 , 最大値 )	ランダムに一つだけfloat値（実数値）を表示
#       4	random.choice(データ)　　　　　　　 データの中でランダムに一つだけ要素を表示
#       5	random.shuffle(リスト)	          　リストの中の要素をシャッフルしてランダムに表示
